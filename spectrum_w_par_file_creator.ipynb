# %% [markdown]
# # For creating a usable parameter file for our selection of files in the Data folder
# The grating lists can be found at https://www.eso.org/sci/facilities/paranal/instruments/flames/inst/specs1.html
#
# This will create a CSV with predefined parameters for the giraffe settings that you specify manually.

# %%
from astropy.io import fits
import pandas as pd
import numpy as np
import os
from os import listdir
from os.path import isfile, join

# %%
os.chdir('../Parameter_files')
par=fits.open('GES_iDR6_WG15_Recommended_with_sflags__mode_normal_091221.fits')

# %%
par[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 6914 / length of dimension 1
# NAXIS2  =               114917 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                  434 / number of table fields
# EXTNAME = 'WGParametersWGAbundances' / Type of GES results in extension
# TTYPE1  = 'CNAME   '           / ESO object name (primary identifier)
# TFORM1  = '16A     '           / data format of field: ASCII Character
# TTYPE2  = 'CNAME_iDR6_orig'    / GES object name from coordinates (old)
# TFORM2  = '33A     '           / data format of field: ASCII Character
# TTYPE3  = 'GAIA_eDR3_ID'       / Gaia eDR3 cross-match source identifier
# TFORM3  = 'K       '           / data format of field: 2-byte INTEGER
# TNULL3  =               999999 / NULL value column 3
# TTYPE4  = 'DIST_GAIA'          / Distance to the Gaia eDR3 cross-match
# TFORM4  = 'D       '           / data format of field: 8-byte DOUBLE
# TTYPE5  = 'GES_FLD '           / GES field name from CASU
# TFORM5  = '12A     '           / data format of field: ASCII Character
# TTYPE6  = 'OBJECT  '           / GES object name from OB
# TFORM6  = '100A    '           / data format of field: ASCII Character
# TTYPE7  = 'FILENAME'           / Spectral file(s) used for Recommended Result
# TFORM7  = '3680A   '           / data format of field: ASCII Character
# TTYPE8  = 'GES_TYPE'           / GES Classification System of Target Programmes
# TFORM8  = '26A     '           / data format of field: ASCII Character
# TTYPE9  = 'REC_SETUP'          / Recommended Parameters taken from this Setup
# TFORM9  = '44A     '           / data format of field: ASCII Character
# TTYPE10 = 'RAVAIL_SETUP'       / Results available from these Setups
# TFORM10 = '70A     '           / data format of field: ASCII Character
# TTYPE11 = 'SETUP   '           / These Grating Setups available for analysis
# TFORM11 = '85A     '           / data format of field: ASCII Character
# TTYPE12 = 'REC_WG  '           / Recommended Results from this GES Working Group
# TFORM12 = '4A      '           / data format of field: ASCII Character
# TTYPE13 = 'RAVAIL_WG'          / Results available from these WGs
# TFORM13 = '19A     '           / data format of field: ASCII Character
# TTYPE14 = 'WG      '           / GES Working Group associated to Setup
# TFORM14 = '19A     '           / data format of field: ASCII Character
# TTYPE15 = 'RA      '           / Object Right Ascension
# TFORM15 = 'D       '           / data format of field: 8-byte DOUBLE
# TUNIT15 = 'Degrees '           / physical unit of field
# TTYPE16 = 'DEC     '           / Object Declination
# TFORM16 = 'D       '           / data format of field: 8-byte DOUBLE
# TUNIT16 = 'Degrees '           / physical unit of field
# TTYPE17 = 'SNR     '           / S/N ratio from CASU/Arcetri pipeline
# TFORM17 = 'E       '           / data format of field: 4-byte REAL
# TTYPE18 = 'TEFF    '           / Effective Temperature
# TFORM18 = 'E       '           / data format of field: 4-byte REAL
# TUNIT18 = 'K       '           / physical unit of field
# TTYPE19 = 'E_TEFF  '           / Error on TEFF
# TFORM19 = 'E       '           / data format of field: 4-byte REAL
# TUNIT19 = 'K       '           / physical unit of field
# TTYPE20 = 'NN_TEFF '           / Number of Node results used for TEFF
# TFORM20 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL20 =                   -1 / NULL value column 20
# TTYPE21 = 'ENN_TEFF'           / Error on TEFF from Node errors
# TFORM21 = 'E       '           / data format of field: 4-byte REAL
# TUNIT21 = 'K       '           / physical unit of field
# TTYPE22 = 'NNE_TEFF'           / Number of Node results used for ENN_TEFF
# TFORM22 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL22 =                   -1 / NULL value column 22
# TTYPE23 = 'SYS_ERR_TEFF'       / Systematic Error of the Effective Temperature
# TFORM23 = 'E       '           / data format of field: 4-byte REAL
# TUNIT23 = 'K       '           / physical unit of field
# TTYPE24 = 'LOGG    '           / Log Surface Gravity (gravity in cms$^{-2}$)
# TFORM24 = 'E       '           / data format of field: 4-byte REAL
# TUNIT24 = 'dex     '           / physical unit of field
# TTYPE25 = 'E_LOGG  '           / Error on LOGG
# TFORM25 = 'E       '           / data format of field: 4-byte REAL
# TUNIT25 = 'dex     '           / physical unit of field
# TTYPE26 = 'NN_LOGG '           / Number of node results used for LOGG
# TFORM26 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL26 =                   -1 / NULL value column 26
# TTYPE27 = 'ENN_LOGG'           / Error on LOGG from Node errors
# TFORM27 = 'E       '           / data format of field: 4-byte REAL
# TUNIT27 = 'dex     '           / physical unit of field
# TTYPE28 = 'NNE_LOGG'           / Number of node results used for ENN_LOGG
# TFORM28 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL28 =                   -1 / NULL value column 28
# TTYPE29 = 'SYS_ERR_LOGG'       / Systematic Error of the Log Surface Gravity
# TFORM29 = 'E       '           / data format of field: 4-byte REAL
# TUNIT29 = 'dex     '           / physical unit of field
# TTYPE30 = 'LIM_LOGG'           / Flag on LOGG
# TFORM30 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL30 =                   -1 / NULL value column 30
# TTYPE31 = 'FEH     '           / Metallicity from Fe lines
# TFORM31 = 'E       '           / data format of field: 4-byte REAL
# TUNIT31 = 'dex     '           / physical unit of field
# TTYPE32 = 'E_FEH   '           / Error on FEH
# TFORM32 = 'E       '           / data format of field: 4-byte REAL
# TUNIT32 = 'dex     '           / physical unit of field
# TTYPE33 = 'NN_FEH  '           / Number of node results used for FEH
# TFORM33 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL33 =                   -1 / NULL value column 33
# TTYPE34 = 'ENN_FEH '           / Error on FEH from Node errors
# TFORM34 = 'E       '           / data format of field: 4-byte REAL
# TUNIT34 = 'dex     '           / physical unit of field
# TTYPE35 = 'NNE_FEH '           / Number of node results used for ENN_FEH
# TFORM35 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL35 =                   -1 / NULL value column 35
# TTYPE36 = 'SYS_ERR_FEH'        / Systematic Error of the Metallicity from Fe
# TFORM36 = 'E       '           / data format of field: 4-byte REAL
# TUNIT36 = 'dex     '           / physical unit of field
# TTYPE37 = 'XI      '           / Microturbulence
# TFORM37 = 'E       '           / data format of field: 4-byte REAL
# TUNIT37 = 'km s-1  '           / physical unit of field
# TTYPE38 = 'E_XI    '           / Error on XI
# TFORM38 = 'E       '           / data format of field: 4-byte REAL
# TUNIT38 = 'km s-1  '           / physical unit of field
# TTYPE39 = 'NN_XI   '           / Number of Node results used for XI
# TFORM39 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL39 =                   -1 / NULL value column 39
# TTYPE40 = 'ENN_XI  '           / Error on XI from Node errors
# TFORM40 = 'E       '           / data format of field: 4-byte REAL
# TUNIT40 = 'km s-1  '           / physical unit of field
# TTYPE41 = 'NNE_XI  '           / Number of Node results used for ENN_XI
# TFORM41 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL41 =                   -1 / NULL value column 41
# TTYPE42 = 'VRAD    '           / Recommended Radial Velocity
# TFORM42 = 'E       '           / data format of field: 4-byte REAL
# TUNIT42 = 'km s-1  '           / physical unit of field
# TTYPE43 = 'E_VRAD  '           / Error on VRAD
# TFORM43 = 'E       '           / data format of field: 4-byte REAL
# TUNIT43 = 'km s-1  '           / physical unit of field
# TTYPE44 = 'PROV_VRAD'          / Provenance of VRAD & VSINI by source and Setup
# TFORM44 = '48A     '           / data format of field: ASCII Character
# TTYPE45 = 'VRAD_OFFSET'        / Offset of VRAD calculated per Setup to HR10
# TFORM45 = 'E       '           / data format of field: 4-byte REAL
# TUNIT45 = 'km s-1  '           / physical unit of field
# TTYPE46 = 'VRAD_FILENAME'      / Spectral file(s) used for Recommended VRAD
# TFORM46 = '388A    '           / data format of field: ASCII Character
# TTYPE47 = 'VRAD_FLAG'          / Flag for the VRAD inter-setup consistency
# TFORM47 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL47 =                   -1 / NULL value column 47
# TTYPE48 = 'NF_VRAD_FLAG'       / Number of spectra used for VRAD_FLAG
# TFORM48 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL48 =                   -1 / NULL value column 48
# TTYPE49 = 'VSINI   '           / Recommended Rotational Velocity
# TFORM49 = 'E       '           / data format of field: 4-byte REAL
# TUNIT49 = 'km s-1  '           / physical unit of field
# TTYPE50 = 'E_VSINI '           / Error on VSINI
# TFORM50 = 'E       '           / data format of field: 4-byte REAL
# TUNIT50 = 'km s-1  '           / physical unit of field
# TTYPE51 = 'LIM_VSINI'          / Flag on upper limits of VSINI
# TFORM51 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL51 =                   -1 / NULL value column 51
# TTYPE52 = 'TEFF_IRFM'          / IRFM weighed average from 2MASS J,H,Ks Bands
# TFORM52 = 'E       '           / data format of field: 4-byte REAL
# TUNIT52 = 'K       '           / physical unit of field
# TTYPE53 = 'E_TEFF_IRFM'        / Error on TEFF_IRFM
# TFORM53 = 'E       '           / data format of field: 4-byte REAL
# TUNIT53 = 'K       '           / physical unit of field
# TTYPE54 = 'FBOL_IRFM'          / Bolometric Flux from IRFM
# TFORM54 = 'E       '           / data format of field: 4-byte REAL
# TUNIT54 = 'erg/cm$^2$/s'       / physical unit of field
# TTYPE55 = 'LI1     '           / Neutral Lithium Abundance in log$\epsilon$(X)
# TFORM55 = 'E       '           / data format of field: 4-byte REAL
# TUNIT55 = 'dex     '           / physical unit of field
# TTYPE56 = 'UPPER_COMBINED_LI1' / Flag on LI1 measurement type
# TFORM56 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL56 =                   -1 / NULL value column 56
# TTYPE57 = 'E_LI1   '           / Error on LI1
# TFORM57 = 'E       '           / data format of field: 4-byte REAL
# TUNIT57 = 'dex     '           / physical unit of field
# TTYPE58 = 'NN_LI1  '           / Number of Node results used for LI1
# TFORM58 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL58 =                   -1 / NULL value column 58
# TTYPE59 = 'ENN_LI1 '           / Error on LI1 from Node errors
# TFORM59 = 'E       '           / data format of field: 4-byte REAL
# TUNIT59 = 'dex     '           / physical unit of field
# TTYPE60 = 'NL_LI1  '           / Number of Spectral Lines used for LI1
# TFORM60 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL60 =                   -1 / NULL value column 60
# TTYPE61 = 'PROVENANCE_LI1'     / WG from which LI1 is sourced
# TFORM61 = '4A      '           / data format of field: ASCII Character
# TTYPE62 = 'VEIL    '           / Veiling
# TFORM62 = 'E       '           / data format of field: 4-byte REAL
# TTYPE63 = 'E_VEIL  '           / Error on VEIL
# TFORM63 = 'E       '           / data format of field: 4-byte REAL
# TTYPE64 = 'EW_LI   '           / Li(6708A) equivalent width
# TFORM64 = 'E       '           / data format of field: 4-byte REAL
# TUNIT64 = 'mAngstroms'         / physical unit of field
# TTYPE65 = 'LIM_EW_LI'          / Flag on EW_LI
# TFORM65 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL65 =                   -1 / NULL value column 65
# TTYPE66 = 'E_EW_LI '           / Error on EW_LI
# TFORM66 = 'E       '           / data format of field: 4-byte REAL
# TUNIT66 = 'mAngstroms'         / physical unit of field
# TTYPE67 = 'PROVENANCE_EW_LI'   / WG from which EW_LI is sourced
# TFORM67 = '4A      '           / data format of field: ASCII Character
# TTYPE68 = 'EWC_LI  '           / Blends-corrected Li(6708A) equivalent width
# TFORM68 = 'E       '           / data format of field: 4-byte REAL
# TUNIT68 = 'mAngstroms'         / physical unit of field
# TTYPE69 = 'LIM_EWC_LI'         / Flag on EWC_LI
# TFORM69 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL69 =                   -1 / NULL value column 69
# TTYPE70 = 'E_EWC_LI'           / Error on EWC_LI
# TFORM70 = 'E       '           / data format of field: 4-byte REAL
# TUNIT70 = 'mAngstroms'         / physical unit of field
# TTYPE71 = 'EW_HA_ACC'          / Halpha EW: accretion
# TFORM71 = 'E       '           / data format of field: 4-byte REAL
# TUNIT71 = 'Angstroms'          / physical unit of field
# TTYPE72 = 'E_EW_HA_ACC'        / Error on EW_HA_ACC
# TFORM72 = 'E       '           / data format of field: 4-byte REAL
# TUNIT72 = 'Angstroms'          / physical unit of field
# TTYPE73 = 'HA10    '           / Halpha EW at 10% of peak - accretion
# TFORM73 = 'E       '           / data format of field: 4-byte REAL
# TUNIT73 = 'km s-1  '           / physical unit of field
# TTYPE74 = 'E_HA10  '           / Error on HA10
# TFORM74 = 'E       '           / data format of field: 4-byte REAL
# TUNIT74 = 'km s-1  '           / physical unit of field
# TTYPE75 = 'EW_HA_CHR'          / Halpha EW: chromospheric activity
# TFORM75 = 'E       '           / data format of field: 4-byte REAL
# TUNIT75 = 'Angstroms'          / physical unit of field
# TTYPE76 = 'E_EW_HA_CHR'        / Error on ewHA_CHR
# TFORM76 = 'E       '           / data format of field: 4-byte REAL
# TUNIT76 = 'Angstroms'          / physical unit of field
# TTYPE77 = 'FHA_CHR '           / H-alpha chromospheric flux
# TFORM77 = 'E       '           / data format of field: 4-byte REAL
# TUNIT77 = 'erg/cm$^2$/s'       / physical unit of field
# TTYPE78 = 'E_FHA_CHR'          / Error on FHA_CHR
# TFORM78 = 'E       '           / data format of field: 4-byte REAL
# TUNIT78 = 'erg/cm$^2$/s'       / physical unit of field
# TTYPE79 = 'FWZI    '           / H-alpha Full Width at Zero Intensity(accretion)
# TFORM79 = 'E       '           / data format of field: 4-byte REAL
# TUNIT79 = 'Angstroms'          / physical unit of field
# TTYPE80 = 'E_FWZI  '           / Error on FWZI
# TFORM80 = 'E       '           / data format of field: 4-byte REAL
# TUNIT80 = 'Angstroms'          / physical unit of field
# TTYPE81 = 'EW_HB_CHR'          / Hbeta EW: chromospheric activity
# TFORM81 = 'E       '           / data format of field: 4-byte REAL
# TUNIT81 = 'Angstroms'          / physical unit of field
# TTYPE82 = 'E_EW_HB_CHR'        / Error on EW_HB_CHR
# TFORM82 = 'E       '           / data format of field: 4-byte REAL
# TUNIT82 = 'Angstroms'          / physical unit of field
# TTYPE83 = 'FHB_CHR '           / H-beta chromospheric flux
# TFORM83 = 'E       '           / data format of field: 4-byte REAL
# TUNIT83 = 'erg/cm$^2$/s'       / physical unit of field
# TTYPE84 = 'E_FHB_CHR'          / Error on FHB_CHR
# TFORM84 = 'E       '           / data format of field: 4-byte REAL
# TUNIT84 = 'erg/cm$^2$/s'       / physical unit of field
# TTYPE85 = 'LOG_MDOT_ACC'       / The log of the accretion rate
# TFORM85 = 'E       '           / data format of field: 4-byte REAL
# TUNIT85 = 'Msolar/yr'          / physical unit of field
# TTYPE86 = 'E_LOG_MDOT_ACC'     / Error on LOG_MDOT_ACC
# TFORM86 = 'E       '           / data format of field: 4-byte REAL
# TUNIT86 = 'Msolar/yr'          / physical unit of field
# TTYPE87 = 'GAMMA   '           / Gravity sensitive spectral index
# TFORM87 = 'E       '           / data format of field: 4-byte REAL
# TTYPE88 = 'E_GAMMA '           / Error on GAMMA
# TFORM88 = 'E       '           / data format of field: 4-byte REAL
# TTYPE89 = 'PECULI  '           / Peculiarity Flag(s): WG14 Dict.1000-2999
# TFORM89 = '186A    '           / data format of field: ASCII Character
# TTYPE90 = 'TECH    '           / Technical Flag(s): WG14 Dict.9000-15000
# TFORM90 = '850A    '           / data format of field: ASCII Character
# TTYPE91 = 'EW_LI_UNVEIL'       / Veiling-corrected Li(6708A) equivalent width
# TFORM91 = 'E       '           / data format of field: 4-byte REAL
# TUNIT91 = 'mAngstroms'         / physical unit of field
# TTYPE92 = 'LIM_EW_LI_UNVEIL'   / Flag on EW_LI_UNVEIL
# TFORM92 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL92 =                   -1 / NULL value column 92
# TTYPE93 = 'E_EW_LI_UNVEIL'     / Error on EW_LI_UNVEIL
# TFORM93 = 'E       '           / data format of field: 4-byte REAL
# TUNIT93 = 'mAngstroms'         / physical unit of field
# TTYPE94 = 'HE1     '           / Neutral Helium Abundance
# TFORM94 = 'E       '           / data format of field: 4-byte REAL
# TUNIT94 = 'dex     '           / physical unit of field
# TTYPE95 = 'UPPER_COMBINED_HE1' / Flag on HE1 measurement type
# TFORM95 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL95 =                   -1 / NULL value column 95
# TTYPE96 = 'E_HE1   '           / Error on HE1
# TFORM96 = 'E       '           / data format of field: 4-byte REAL
# TUNIT96 = 'dex     '           / physical unit of field
# TTYPE97 = 'NN_HE1  '           / Number of Node results used for HE1
# TFORM97 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL97 =                   -1 / NULL value column 97
# TTYPE98 = 'ENN_HE1 '           / Error on HE1 from Node errors
# TFORM98 = 'E       '           / data format of field: 4-byte REAL
# TUNIT98 = 'dex     '           / physical unit of field
# TTYPE99 = 'NL_HE1  '           / Number of Spectral Lines used for HE1
# TFORM99 = 'I       '           / data format of field: 2-byte INTEGER
# TNULL99 =                   -1 / NULL value column 99
# TTYPE100= 'PROVENANCE_HE1'     / WG from which HE1 is sourced
# TFORM100= '4A      '           / data format of field: ASCII Character
# TTYPE101= 'C1      '           / Neutral Carbon Abundance
# TFORM101= 'E       '           / data format of field: 4-byte REAL
# TUNIT101= 'dex     '           / physical unit of field
# TTYPE102= 'UPPER_COMBINED_C1'  / Flag on C1 measurement type
# TFORM102= 'I       '           / data format of field: 2-byte INTEGER
# TNULL102=                   -1 / NULL value column 102
# TTYPE103= 'E_C1    '           / Error on C1
# TFORM103= 'E       '           / data format of field: 4-byte REAL
# TUNIT103= 'dex     '           / physical unit of field
# TTYPE104= 'NN_C1   '           / Number of Node results used for C1
# TFORM104= 'I       '           / data format of field: 2-byte INTEGER
# TNULL104=                   -1 / NULL value column 104
# TTYPE105= 'ENN_C1  '           / Error on C1 from Node errors
# TFORM105= 'E       '           / data format of field: 4-byte REAL
# TUNIT105= 'dex     '           / physical unit of field
# TTYPE106= 'NL_C1   '           / Number of Spectral lines used for C1
# TFORM106= 'I       '           / data format of field: 2-byte INTEGER
# TNULL106=                   -1 / NULL value column 106
# TTYPE107= 'PROVENANCE_C1'      / WG from which C1 is sourced
# TFORM107= '4A      '           / data format of field: ASCII Character
# TTYPE108= 'C2      '           / Ionised Carbon Abundance
# TFORM108= 'E       '           / data format of field: 4-byte REAL
# TUNIT108= 'dex     '           / physical unit of field
# TTYPE109= 'UPPER_C2'           / Flag on C2 measurement type
# TFORM109= 'I       '           / data format of field: 2-byte INTEGER
# TNULL109=                   -1 / NULL value column 109
# TTYPE110= 'E_C2    '           / Error on C2
# TFORM110= 'E       '           / data format of field: 4-byte REAL
# TUNIT110= 'dex     '           / physical unit of field
# TTYPE111= 'NN_C2   '           / Number of Node results used for C2
# TFORM111= 'I       '           / data format of field: 2-byte INTEGER
# TNULL111=                   -1 / NULL value column 111
# TTYPE112= 'ENN_C2  '           / Error on C2 from Node errors
# TFORM112= 'E       '           / data format of field: 4-byte REAL
# TUNIT112= 'dex     '           / physical unit of field
# TTYPE113= 'NL_C2   '           / Number of Spectral lines used for C2
# TFORM113= 'I       '           / data format of field: 2-byte INTEGER
# TNULL113=                   -1 / NULL value column 113
# TTYPE114= 'PROVENANCE_C2'      / WG from which C2 is sourced
# TFORM114= '4A      '           / data format of field: ASCII Character
# TTYPE115= 'C3      '           / Doubly Ionised Carbon Abundance
# TFORM115= 'E       '           / data format of field: 4-byte REAL
# TUNIT115= 'dex     '           / physical unit of field
# TTYPE116= 'UPPER_C3'           / Flag on C3 measurement type
# TFORM116= 'I       '           / data format of field: 2-byte INTEGER
# TNULL116=                   -1 / NULL value column 116
# TTYPE117= 'E_C3    '           / Error on C3
# TFORM117= 'E       '           / data format of field: 4-byte REAL
# TUNIT117= 'dex     '           / physical unit of field
# TTYPE118= 'NN_C3   '           / Number of Node results used for C3
# TFORM118= 'I       '           / data format of field: 2-byte INTEGER
# TNULL118=                   -1 / NULL value column 118
# TTYPE119= 'ENN_C3  '           / Error on C3 from Node errors
# TFORM119= 'E       '           / data format of field: 4-byte REAL
# TUNIT119= 'dex     '           / physical unit of field
# TTYPE120= 'NL_C3   '           / Number of Spectral lines used for C3
# TFORM120= 'I       '           / data format of field: 2-byte INTEGER
# TNULL120=                   -1 / NULL value column 120
# TTYPE121= 'PROVENANCE_C3'      / WG from which C3 is sourced
# TFORM121= '4A      '           / data format of field: ASCII Character
# TTYPE122= 'C_C2    '           / Carbon Abundance from C2 Molecular Bands
# TFORM122= 'E       '           / data format of field: 4-byte REAL
# TUNIT122= 'dex     '           / physical unit of field
# TTYPE123= 'UPPER_C_C2'         / Flag on C_C2 measurement type
# TFORM123= 'I       '           / data format of field: 2-byte INTEGER
# TNULL123=                   -1 / NULL value column 123
# TTYPE124= 'E_C_C2  '           / Error on C_C2
# TFORM124= 'E       '           / data format of field: 4-byte REAL
# TUNIT124= 'dex     '           / physical unit of field
# TTYPE125= 'NN_C_C2 '           / Number of Node results used for C_C2
# TFORM125= 'I       '           / data format of field: 2-byte INTEGER
# TNULL125=                   -1 / NULL value column 125
# TTYPE126= 'ENN_C_C2'           / Error on C_C2 from Node errors
# TFORM126= 'E       '           / data format of field: 4-byte REAL
# TUNIT126= 'dex     '           / physical unit of field
# TTYPE127= 'NL_C_C2 '           / Number of Molecular Bands used for C_C2
# TFORM127= 'I       '           / data format of field: 2-byte INTEGER
# TNULL127=                   -1 / NULL value column 127
# TTYPE128= 'PROVENANCE_C_C2'    / WG from which C_C2 is sourced
# TFORM128= '4A      '           / data format of field: ASCII Character
# TTYPE129= 'N2      '           / Ionised Nitrogen Abundance
# TFORM129= 'E       '           / data format of field: 4-byte REAL
# TUNIT129= 'dex     '           / physical unit of field
# TTYPE130= 'UPPER_N2'           / Flag on N2 measurement type
# TFORM130= 'I       '           / data format of field: 2-byte INTEGER
# TNULL130=                   -1 / NULL value column 130
# TTYPE131= 'E_N2    '           / Error on N2
# TFORM131= 'E       '           / data format of field: 4-byte REAL
# TUNIT131= 'dex     '           / physical unit of field
# TTYPE132= 'NN_N2   '           / Number of Node results used for N2
# TFORM132= 'I       '           / data format of field: 2-byte INTEGER
# TNULL132=                   -1 / NULL value column 132
# TTYPE133= 'ENN_N2  '           / Error on N2 from Node errors
# TFORM133= 'E       '           / data format of field: 4-byte REAL
# TUNIT133= 'dex     '           / physical unit of field
# TTYPE134= 'NL_N2   '           / Number of Spectral lines used for N2
# TFORM134= 'I       '           / data format of field: 2-byte INTEGER
# TNULL134=                   -1 / NULL value column 134
# TTYPE135= 'PROVENANCE_N2'      / WG from which N2 is sourced
# TFORM135= '4A      '           / data format of field: ASCII Character
# TTYPE136= 'N3      '           / Doubly Ionised Nitrogen Abundance
# TFORM136= 'E       '           / data format of field: 4-byte REAL
# TUNIT136= 'dex     '           / physical unit of field
# TTYPE137= 'UPPER_N3'           / Flag on N3 measurement type
# TFORM137= 'I       '           / data format of field: 2-byte INTEGER
# TNULL137=                   -1 / NULL value column 137
# TTYPE138= 'E_N3    '           / Error on N3
# TFORM138= 'E       '           / data format of field: 4-byte REAL
# TUNIT138= 'dex     '           / physical unit of field
# TTYPE139= 'NN_N3   '           / Number of Node results used for N3
# TFORM139= 'I       '           / data format of field: 2-byte INTEGER
# TNULL139=                   -1 / NULL value column 139
# TTYPE140= 'ENN_N3  '           / Error on N3 from Node errors
# TFORM140= 'E       '           / data format of field: 4-byte REAL
# TUNIT140= 'dex     '           / physical unit of field
# TTYPE141= 'NL_N3   '           / Number of Spectral lines used for N3
# TFORM141= 'I       '           / data format of field: 2-byte INTEGER
# TNULL141=                   -1 / NULL value column 141
# TTYPE142= 'PROVENANCE_N3'      / WG from which N3 is sourced
# TFORM142= '4A      '           / data format of field: ASCII Character
# TTYPE143= 'N_CN    '           / Nitrogen Abundance from CN Molecular Bands
# TFORM143= 'E       '           / data format of field: 4-byte REAL
# TUNIT143= 'dex     '           / physical unit of field
# TTYPE144= 'UPPER_N_CN'         / Flag on N_CN measurement type
# TFORM144= 'I       '           / data format of field: 2-byte INTEGER
# TNULL144=                   -1 / NULL value column 144
# TTYPE145= 'E_N_CN  '           / Error on N_CN
# TFORM145= 'E       '           / data format of field: 4-byte REAL
# TUNIT145= 'dex     '           / physical unit of field
# TTYPE146= 'NN_N_CN '           / Number of Node results used for N_CN
# TFORM146= 'I       '           / data format of field: 2-byte INTEGER
# TNULL146=                   -1 / NULL value column 146
# TTYPE147= 'ENN_N_CN'           / Error on N_CN from Node errors
# TFORM147= 'E       '           / data format of field: 4-byte REAL
# TUNIT147= 'dex     '           / physical unit of field
# TTYPE148= 'NL_N_CN '           / Number of Molecular Bands used for N_CN
# TFORM148= 'I       '           / data format of field: 2-byte INTEGER
# TNULL148=                   -1 / NULL value column 148
# TTYPE149= 'PROVENANCE_N_CN'    / WG from which N_CN is sourced
# TFORM149= '4A      '           / data format of field: ASCII Character
# TTYPE150= 'O1      '           / Neutral Oxygen Abundance
# TFORM150= 'E       '           / data format of field: 4-byte REAL
# TUNIT150= 'dex     '           / physical unit of field
# TTYPE151= 'UPPER_COMBINED_O1'  / Flag on O1 measurement type
# TFORM151= 'I       '           / data format of field: 2-byte INTEGER
# TNULL151=                   -1 / NULL value column 151
# TTYPE152= 'E_O1    '           / Error on O1
# TFORM152= 'E       '           / data format of field: 4-byte REAL
# TUNIT152= 'dex     '           / physical unit of field
# TTYPE153= 'NN_O1   '           / Number of Node results used for O1
# TFORM153= 'I       '           / data format of field: 2-byte INTEGER
# TNULL153=                   -1 / NULL value column 153
# TTYPE154= 'ENN_O1  '           / Error on O1 from Node errors
# TFORM154= 'E       '           / data format of field: 4-byte REAL
# TUNIT154= 'dex     '           / physical unit of field
# TTYPE155= 'NL_O1   '           / Number of Spectral lines used for O1
# TFORM155= 'I       '           / data format of field: 2-byte INTEGER
# TNULL155=                   -1 / NULL value column 155
# TTYPE156= 'PROVENANCE_O1'      / WG from which O1 is sourced
# TFORM156= '4A      '           / data format of field: ASCII Character
# TTYPE157= 'O2      '           / Ionised Oxygen Abundance
# TFORM157= 'E       '           / data format of field: 4-byte REAL
# TUNIT157= 'dex     '           / physical unit of field
# TTYPE158= 'UPPER_O2'           / Flag on O2 measurement type
# TFORM158= 'I       '           / data format of field: 2-byte INTEGER
# TNULL158=                   -1 / NULL value column 158
# TTYPE159= 'E_O2    '           / Error on O2
# TFORM159= 'E       '           / data format of field: 4-byte REAL
# TUNIT159= 'dex     '           / physical unit of field
# TTYPE160= 'NN_O2   '           / Number of Node results used for O2
# TFORM160= 'I       '           / data format of field: 2-byte INTEGER
# TNULL160=                   -1 / NULL value column 160
# TTYPE161= 'ENN_O2  '           / Error on O2 from Node errors
# TFORM161= 'E       '           / data format of field: 4-byte REAL
# TUNIT161= 'dex     '           / physical unit of field
# TTYPE162= 'NL_O2   '           / Number of Spectral lines used for O2
# TFORM162= 'I       '           / data format of field: 2-byte INTEGER
# TNULL162=                   -1 / NULL value column 162
# TTYPE163= 'PROVENANCE_O2'      / WG from which O2 is sourced
# TFORM163= '4A      '           / data format of field: ASCII Character
# TTYPE164= 'NE1     '           / Neutral Neon Abundance
# TFORM164= 'E       '           / data format of field: 4-byte REAL
# TUNIT164= 'dex     '           / physical unit of field
# TTYPE165= 'UPPER_COMBINED_NE1' / Flag on NE1 measurement type
# TFORM165= 'I       '           / data format of field: 2-byte INTEGER
# TNULL165=                   -1 / NULL value column 165
# TTYPE166= 'E_NE1   '           / Error on NE1
# TFORM166= 'E       '           / data format of field: 4-byte REAL
# TUNIT166= 'dex     '           / physical unit of field
# TTYPE167= 'NN_NE1  '           / Number of Node results used for NE1
# TFORM167= 'I       '           / data format of field: 2-byte INTEGER
# TNULL167=                   -1 / NULL value column 167
# TTYPE168= 'ENN_NE1 '           / Error on NE1 from Node errors
# TFORM168= 'E       '           / data format of field: 4-byte REAL
# TUNIT168= 'dex     '           / physical unit of field
# TTYPE169= 'NL_NE1  '           / Number of Spectral lines used for NE1
# TFORM169= 'I       '           / data format of field: 2-byte INTEGER
# TNULL169=                   -1 / NULL value column 169
# TTYPE170= 'PROVENANCE_NE1'     / WG from which NE1 is sourced
# TFORM170= '4A      '           / data format of field: ASCII Character
# TTYPE171= 'NA1     '           / Neutral Sodium Abundance
# TFORM171= 'E       '           / data format of field: 4-byte REAL
# TUNIT171= 'dex     '           / physical unit of field
# TTYPE172= 'UPPER_COMBINED_NA1' / Flag on NA1 measurement type
# TFORM172= 'I       '           / data format of field: 2-byte INTEGER
# TNULL172=                   -1 / NULL value column 172
# TTYPE173= 'E_NA1   '           / Error on NA1
# TFORM173= 'E       '           / data format of field: 4-byte REAL
# TUNIT173= 'dex     '           / physical unit of field
# TTYPE174= 'NN_NA1  '           / Number of Node results used for NA1
# TFORM174= 'I       '           / data format of field: 2-byte INTEGER
# TNULL174=                   -1 / NULL value column 174
# TTYPE175= 'ENN_NA1 '           / Error on NA1 from Node errors
# TFORM175= 'E       '           / data format of field: 4-byte REAL
# TUNIT175= 'dex     '           / physical unit of field
# TTYPE176= 'NL_NA1  '           / Number of Spectral lines used for NA1
# TFORM176= 'I       '           / data format of field: 2-byte INTEGER
# TNULL176=                   -1 / NULL value column 176
# TTYPE177= 'PROVENANCE_NA1'     / WG from which NA1 is sourced
# TFORM177= '4A      '           / data format of field: ASCII Character
# TTYPE178= 'MG1     '           / Neutral Magnesium Abundance
# TFORM178= 'E       '           / data format of field: 4-byte REAL
# TUNIT178= 'dex     '           / physical unit of field
# TTYPE179= 'UPPER_COMBINED_MG1' / Flag on MG1 measurement type
# TFORM179= 'I       '           / data format of field: 2-byte INTEGER
# TNULL179=                   -1 / NULL value column 179
# TTYPE180= 'E_MG1   '           / Error on MG1
# TFORM180= 'E       '           / data format of field: 4-byte REAL
# TUNIT180= 'dex     '           / physical unit of field
# TTYPE181= 'NN_MG1  '           / Number of Node results used for MG1
# TFORM181= 'I       '           / data format of field: 2-byte INTEGER
# TNULL181=                   -1 / NULL value column 181
# TTYPE182= 'ENN_MG1 '           / Error on MG1 from Node errors
# TFORM182= 'E       '           / data format of field: 4-byte REAL
# TUNIT182= 'dex     '           / physical unit of field
# TTYPE183= 'NL_MG1  '           / Number of Spectral lines used for MG1
# TFORM183= 'I       '           / data format of field: 2-byte INTEGER
# TNULL183=                   -1 / NULL value column 183
# TTYPE184= 'PROVENANCE_MG1'     / WG from which MG1 is sourced
# TFORM184= '4A      '           / data format of field: ASCII Character
# TTYPE185= 'MG2     '           / Ionised Magnesium Abundance
# TFORM185= 'E       '           / data format of field: 4-byte REAL
# TUNIT185= 'dex     '           / physical unit of field
# TTYPE186= 'UPPER_MG2'          / Flag on MG2 measurement type
# TFORM186= 'I       '           / data format of field: 2-byte INTEGER
# TNULL186=                   -1 / NULL value column 186
# TTYPE187= 'E_MG2   '           / Error on MG2
# TFORM187= 'E       '           / data format of field: 4-byte REAL
# TUNIT187= 'dex     '           / physical unit of field
# TTYPE188= 'NN_MG2  '           / Number of Node results used for MG2
# TFORM188= 'I       '           / data format of field: 2-byte INTEGER
# TNULL188=                   -1 / NULL value column 188
# TTYPE189= 'ENN_MG2 '           / Error on MG2 from Node errors
# TFORM189= 'E       '           / data format of field: 4-byte REAL
# TUNIT189= 'dex     '           / physical unit of field
# TTYPE190= 'NL_MG2  '           / Number of Spectral lines used for MG2
# TFORM190= 'I       '           / data format of field: 2-byte INTEGER
# TNULL190=                   -1 / NULL value column 190
# TTYPE191= 'PROVENANCE_MG2'     / WG from which MG2 is sourced
# TFORM191= '4A      '           / data format of field: ASCII Character
# TTYPE192= 'AL1     '           / Neutral Aluminium Abundance
# TFORM192= 'E       '           / data format of field: 4-byte REAL
# TUNIT192= 'dex     '           / physical unit of field
# TTYPE193= 'UPPER_COMBINED_AL1' / Flag on AL1 measurement type
# TFORM193= 'I       '           / data format of field: 2-byte INTEGER
# TNULL193=                   -1 / NULL value column 193
# TTYPE194= 'E_AL1   '           / Error on AL1
# TFORM194= 'E       '           / data format of field: 4-byte REAL
# TUNIT194= 'dex     '           / physical unit of field
# TTYPE195= 'NN_AL1  '           / Number of Node results used for AL1
# TFORM195= 'I       '           / data format of field: 2-byte INTEGER
# TNULL195=                   -1 / NULL value column 195
# TTYPE196= 'ENN_AL1 '           / Error on AL1 from Node errors
# TFORM196= 'E       '           / data format of field: 4-byte REAL
# TUNIT196= 'dex     '           / physical unit of field
# TTYPE197= 'NL_AL1  '           / Number of Spectral Lines used for AL1
# TFORM197= 'I       '           / data format of field: 2-byte INTEGER
# TNULL197=                   -1 / NULL value column 197
# TTYPE198= 'PROVENANCE_AL1'     / WG from which AL1 is sourced
# TFORM198= '4A      '           / data format of field: ASCII Character
# TTYPE199= 'AL2     '           / Ionised Aluminium Abundance
# TFORM199= 'E       '           / data format of field: 4-byte REAL
# TUNIT199= 'dex     '           / physical unit of field
# TTYPE200= 'UPPER_AL2'          / Flag on AL2 measurement type
# TFORM200= 'I       '           / data format of field: 2-byte INTEGER
# TNULL200=                   -1 / NULL value column 200
# TTYPE201= 'E_AL2   '           / Error on AL2
# TFORM201= 'E       '           / data format of field: 4-byte REAL
# TUNIT201= 'dex     '           / physical unit of field
# TTYPE202= 'NN_AL2  '           / Number of Node results used for AL2
# TFORM202= 'I       '           / data format of field: 2-byte INTEGER
# TNULL202=                   -1 / NULL value column 202
# TTYPE203= 'ENN_AL2 '           / Error on AL2 from Node errors
# TFORM203= 'E       '           / data format of field: 4-byte REAL
# TUNIT203= 'dex     '           / physical unit of field
# TTYPE204= 'NL_AL2  '           / Number of Spectral Lines used for AL2
# TFORM204= 'I       '           / data format of field: 2-byte INTEGER
# TNULL204=                   -1 / NULL value column 204
# TTYPE205= 'PROVENANCE_AL2'     / WG from which AL2 is sourced
# TFORM205= '4A      '           / data format of field: ASCII Character
# TTYPE206= 'SI1     '           / Neutral Silicon Abundance
# TFORM206= 'E       '           / data format of field: 4-byte REAL
# TUNIT206= 'dex     '           / physical unit of field
# TTYPE207= 'UPPER_COMBINED_SI1' / Flag on SI1 measurement type
# TFORM207= 'I       '           / data format of field: 2-byte INTEGER
# TNULL207=                   -1 / NULL value column 207
# TTYPE208= 'E_SI1   '           / Error on SI1
# TFORM208= 'E       '           / data format of field: 4-byte REAL
# ...
# TFORM362= 'E       '           / data format of field: 4-byte REAL
# TUNIT362= 'dex     '           / physical unit of field
# TTYPE363= 'NN_ZR2  '           / Number of Node results used for ZR2
# TFORM363= 'I       '           / data format of field: 2-byte INTEGER
# TNULL363=                   -1 / NULL value column 363
# TTYPE364= 'ENN_ZR2 '           / Error on ZR2 from Node errors
# TFORM364= 'E       '           / data format of field: 4-byte REAL
# TUNIT364= 'dex     '           / physical unit of field
# TTYPE365= 'NL_ZR2  '           / Number of Spectral Lines used for ZR2
# TFORM365= 'I       '           / data format of field: 2-byte INTEGER
# TNULL365=                   -1 / NULL value column 365
# TTYPE366= 'PROVENANCE_ZR2'     / WG from which ZR2 is sourced
# TFORM366= '4A      '           / data format of field: ASCII Character
# TTYPE367= 'MO1     '           / Neutral Molybdenum Abundance
# TFORM367= 'E       '           / data format of field: 4-byte REAL
# TUNIT367= 'dex     '           / physical unit of field
# TTYPE368= 'UPPER_COMBINED_MO1' / Flag on MO1 measurement type
# TFORM368= 'I       '           / data format of field: 2-byte INTEGER
# TNULL368=                   -1 / NULL value column 368
# TTYPE369= 'E_MO1   '           / Error on MO1
# TFORM369= 'E       '           / data format of field: 4-byte REAL
# TUNIT369= 'dex     '           / physical unit of field
# TTYPE370= 'NN_MO1  '           / Number of Node results used for MO1
# TFORM370= 'I       '           / data format of field: 2-byte INTEGER
# TNULL370=                   -1 / NULL value column 370
# TTYPE371= 'ENN_MO1 '           / Error on MO1 from Node errors
# TFORM371= 'E       '           / data format of field: 4-byte REAL
# TUNIT371= 'dex     '           / physical unit of field
# TTYPE372= 'NL_MO1  '           / Number of Spectral Lines used for MO1
# TFORM372= 'I       '           / data format of field: 2-byte INTEGER
# TNULL372=                   -1 / NULL value column 372
# TTYPE373= 'PROVENANCE_MO1'     / WG from which MO1 is sourced
# TFORM373= '4A      '           / data format of field: ASCII Character
# TTYPE374= 'BA2     '           / Ionised Barium Abundance
# TFORM374= 'E       '           / data format of field: 4-byte REAL
# TUNIT374= 'dex     '           / physical unit of field
# TTYPE375= 'UPPER_BA2'          / Flag on BA2 measurement type
# TFORM375= 'I       '           / data format of field: 2-byte INTEGER
# TNULL375=                   -1 / NULL value column 375
# TTYPE376= 'E_BA2   '           / Error on BA2
# TFORM376= 'E       '           / data format of field: 4-byte REAL
# TUNIT376= 'dex     '           / physical unit of field
# TTYPE377= 'NN_BA2  '           / Number of Node results used for BA2
# TFORM377= 'I       '           / data format of field: 2-byte INTEGER
# TNULL377=                   -1 / NULL value column 377
# TTYPE378= 'ENN_BA2 '           / Error on BA2 from Node errors
# TFORM378= 'E       '           / data format of field: 4-byte REAL
# TUNIT378= 'dex     '           / physical unit of field
# TTYPE379= 'NL_BA2  '           / Number of Spectral Lines used for BA2
# TFORM379= 'I       '           / data format of field: 2-byte INTEGER
# TNULL379=                   -1 / NULL value column 379
# TTYPE380= 'PROVENANCE_BA2'     / WG from which BA2 is sourced
# TFORM380= '4A      '           / data format of field: ASCII Character
# TTYPE381= 'LA2     '           / Ionised Lathanum Abundance
# TFORM381= 'E       '           / data format of field: 4-byte REAL
# TUNIT381= 'dex     '           / physical unit of field
# TTYPE382= 'UPPER_LA2'          / Flag on LA2 measurement type
# TFORM382= 'I       '           / data format of field: 2-byte INTEGER
# TNULL382=                   -1 / NULL value column 382
# TTYPE383= 'E_LA2   '           / Error on LA2
# TFORM383= 'E       '           / data format of field: 4-byte REAL
# TUNIT383= 'dex     '           / physical unit of field
# TTYPE384= 'NN_LA2  '           / Number of Node results used for LA2
# TFORM384= 'I       '           / data format of field: 2-byte INTEGER
# TNULL384=                   -1 / NULL value column 384
# TTYPE385= 'ENN_LA2 '           / Error on LA2 from Node errors
# TFORM385= 'E       '           / data format of field: 4-byte REAL
# TUNIT385= 'dex     '           / physical unit of field
# TTYPE386= 'NL_LA2  '           / Number of Spectral Lines used for LA2
# TFORM386= 'I       '           / data format of field: 2-byte INTEGER
# TNULL386=                   -1 / NULL value column 386
# TTYPE387= 'PROVENANCE_LA2'     / WG from which LA2 is sourced
# TFORM387= '4A      '           / data format of field: ASCII Character
# TTYPE388= 'CE2     '           / Ionised Cerium Abundance
# TFORM388= 'E       '           / data format of field: 4-byte REAL
# TUNIT388= 'dex     '           / physical unit of field
# TTYPE389= 'UPPER_CE2'          / Flag on CE2 measurement type
# TFORM389= 'I       '           / data format of field: 2-byte INTEGER
# TNULL389=                   -1 / NULL value column 389
# TTYPE390= 'E_CE2   '           / Error on CE2
# TFORM390= 'E       '           / data format of field: 4-byte REAL
# TUNIT390= 'dex     '           / physical unit of field
# TTYPE391= 'NN_CE2  '           / Number of Node results used for CE2
# TFORM391= 'I       '           / data format of field: 2-byte INTEGER
# TNULL391=                   -1 / NULL value column 391
# TTYPE392= 'ENN_CE2 '           / Error on CE2 from Node errors
# TFORM392= 'E       '           / data format of field: 4-byte REAL
# TUNIT392= 'dex     '           / physical unit of field
# TTYPE393= 'NL_CE2  '           / Number of Spectral Lines used for CE2
# TFORM393= 'I       '           / data format of field: 2-byte INTEGER
# TNULL393=                   -1 / NULL value column 393
# TTYPE394= 'PROVENANCE_CE2'     / WG from which CE2 is sourced
# TFORM394= '4A      '           / data format of field: ASCII Character
# TTYPE395= 'PR2     '           / Ionised Praseodymium Abundance
# TFORM395= 'E       '           / data format of field: 4-byte REAL
# TUNIT395= 'dex     '           / physical unit of field
# TTYPE396= 'UPPER_PR2'          / Flag on PR2 measurement type
# TFORM396= 'I       '           / data format of field: 2-byte INTEGER
# TNULL396=                   -1 / NULL value column 396
# TTYPE397= 'E_PR2   '           / Error on PR2
# TFORM397= 'E       '           / data format of field: 4-byte REAL
# TUNIT397= 'dex     '           / physical unit of field
# TTYPE398= 'NN_PR2  '           / Number of Node results used for PR2
# TFORM398= 'I       '           / data format of field: 2-byte INTEGER
# TNULL398=                   -1 / NULL value column 398
# TTYPE399= 'ENN_PR2 '           / Error on PR2 from Node errors
# TFORM399= 'E       '           / data format of field: 4-byte REAL
# TUNIT399= 'dex     '           / physical unit of field
# TTYPE400= 'NL_PR2  '           / Number of Spectral Lines used for PR2
# TFORM400= 'I       '           / data format of field: 2-byte INTEGER
# TNULL400=                   -1 / NULL value column 400
# TTYPE401= 'PROVENANCE_PR2'     / WG from which PR2 is sourced
# TFORM401= '4A      '           / data format of field: ASCII Character
# TTYPE402= 'ND2     '           / Ionised Neodymium Abundance
# TFORM402= 'E       '           / data format of field: 4-byte REAL
# TUNIT402= 'dex     '           / physical unit of field
# TTYPE403= 'UPPER_ND2'          / Flag on ND2 measurement type
# TFORM403= 'I       '           / data format of field: 2-byte INTEGER
# TNULL403=                   -1 / NULL value column 403
# TTYPE404= 'E_ND2   '           / Error on ND2
# TFORM404= 'E       '           / data format of field: 4-byte REAL
# TUNIT404= 'dex     '           / physical unit of field
# TTYPE405= 'NN_ND2  '           / Number of Node results used for ND2
# TFORM405= 'I       '           / data format of field: 2-byte INTEGER
# TNULL405=                   -1 / NULL value column 405
# TTYPE406= 'ENN_ND2 '           / Error on ND2 from Node errors
# TFORM406= 'E       '           / data format of field: 4-byte REAL
# TUNIT406= 'dex     '           / physical unit of field
# TTYPE407= 'NL_ND2  '           / Number of Spectral Lines used for ND2
# TFORM407= 'I       '           / data format of field: 2-byte INTEGER
# TNULL407=                   -1 / NULL value column 407
# TTYPE408= 'PROVENANCE_ND2'     / WG from which ND2 is sourced
# TFORM408= '4A      '           / data format of field: ASCII Character
# TTYPE409= 'SM2     '           / Ionised Samarium Abundance
# TFORM409= 'E       '           / data format of field: 4-byte REAL
# TUNIT409= 'dex     '           / physical unit of field
# TTYPE410= 'UPPER_SM2'          / Flag on SM2 measurement type
# TFORM410= 'I       '           / data format of field: 2-byte INTEGER
# TNULL410=                   -1 / NULL value column 410
# TTYPE411= 'E_SM2   '           / Error on SM2
# TFORM411= 'E       '           / data format of field: 4-byte REAL
# TUNIT411= 'dex     '           / physical unit of field
# TTYPE412= 'NN_SM2  '           / Number of Node results used for SM2
# TFORM412= 'I       '           / data format of field: 2-byte INTEGER
# TNULL412=                   -1 / NULL value column 412
# TTYPE413= 'ENN_SM2 '           / Error on SM2 from Node errors
# TFORM413= 'E       '           / data format of field: 4-byte REAL
# TUNIT413= 'dex     '           / physical unit of field
# TTYPE414= 'NL_SM2  '           / Number of Spectral Lines used for SM2
# TFORM414= 'I       '           / data format of field: 2-byte INTEGER
# TNULL414=                   -1 / NULL value column 414
# TTYPE415= 'PROVENANCE_SM2'     / WG from which SM2 is sourced
# TFORM415= '4A      '           / data format of field: ASCII Character
# TTYPE416= 'EU2     '           / Ionised Europium Abundance
# TFORM416= 'E       '           / data format of field: 4-byte REAL
# TUNIT416= 'dex     '           / physical unit of field
# TTYPE417= 'UPPER_EU2'          / Flag on EU2 measurement type
# TFORM417= 'I       '           / data format of field: 2-byte INTEGER
# TNULL417=                   -1 / NULL value column 417
# TTYPE418= 'E_EU2   '           / Error on EU2
# TFORM418= 'E       '           / data format of field: 4-byte REAL
# TUNIT418= 'dex     '           / physical unit of field
# TTYPE419= 'NN_EU2  '           / Number of Node results used for EU2
# TFORM419= 'I       '           / data format of field: 2-byte INTEGER
# TNULL419=                   -1 / NULL value column 419
# TTYPE420= 'ENN_EU2 '           / Error on EU2 from Node errors
# TFORM420= 'E       '           / data format of field: 4-byte REAL
# TUNIT420= 'dex     '           / physical unit of field
# TTYPE421= 'NL_EU2  '           / Number of Spectral Lines used for EU2
# TFORM421= 'I       '           / data format of field: 2-byte INTEGER
# TNULL421=                   -1 / NULL value column 421
# TTYPE422= 'PROVENANCE_EU2'     / WG from which EU2 is sourced
# TFORM422= '4A      '           / data format of field: ASCII Character
# TTYPE423= 'SFLAG_SNR'          / No result or inaccurate due to low SNR
# TFORM423= 'L       '           / data format of field: Logical (Boolean)
# TTYPE424= 'SFLAG_SRP'          / Spectral Reduction Problem
# TFORM424= 'L       '           / data format of field: Logical (Boolean)
# TTYPE425= 'SFLAG_IPA'          / Incomplete PArameters
# TFORM425= 'L       '           / data format of field: Logical (Boolean)
# TTYPE426= 'SFLAG_SSP'          / Some Suspicious Parameters
# TFORM426= 'L       '           / data format of field: Logical (Boolean)
# TTYPE427= 'SFLAG_SSA'          / Some Suspicious Abundances
# TFORM427= 'L       '           / data format of field: Logical (Boolean)
# TTYPE428= 'SFLAG_NIA'          / No Individual Abundance (except Fe)
# TFORM428= 'L       '           / data format of field: Logical (Boolean)
# TTYPE429= 'SFLAG_PSC'          / Parameter Space Coverage
# TFORM429= 'L       '           / data format of field: Logical (Boolean)
# TTYPE430= 'SFLAG_SRV'          / Suspicious or unreliable Radial Velocity
# TFORM430= 'L       '           / data format of field: Logical (Boolean)
# TTYPE431= 'SFLAG_SRO'          / Suspicious ROtational velocity
# TFORM431= 'L       '           / data format of field: Logical (Boolean)
# TTYPE432= 'SFLAG_SDS'          / Some Discarded Spectra
# TFORM432= 'L       '           / data format of field: Logical (Boolean)
# TTYPE433= 'SFLAG_BIN'          / Detected BINary (SB1 or SBn>=2)
# TFORM433= 'L       '           / data format of field: Logical (Boolean)
# TTYPE434= 'SFLAG_EML'          / EMission Line (any line, not only Halpha)
# TFORM434= 'L       '           / data format of field: Logical (Boolean)

# %%
indices=[1,2,3,4,5,6,7,8,15,16,18,19,23,24,25,29,31,32,36,37,38,42,43,45,87,88]
columns=[par[1].header['TTYPE'+str(i)] for i in indices]

# %%
data=np.array([par[1].data[x] for x in columns]).transpose()

# %%
data=pd.DataFrame(data=data,columns=columns)

# %%
data.columns
# Out:
# Index(['CNAME', 'CNAME_iDR6_orig', 'GAIA_eDR3_ID', 'DIST_GAIA', 'GES_FLD',
#        'OBJECT', 'FILENAME', 'GES_TYPE', 'RA', 'DEC', 'TEFF', 'E_TEFF',
#        'SYS_ERR_TEFF', 'LOGG', 'E_LOGG', 'SYS_ERR_LOGG', 'FEH', 'E_FEH',
#        'SYS_ERR_FEH', 'XI', 'E_XI', 'VRAD', 'E_VRAD', 'VRAD_OFFSET', 'GAMMA',
#        'E_GAMMA'],
#       dtype='object')

# %%
os.chdir("../Data")  #change to data set folder and get the file names
mypath=os.getcwd()
spectra = [f for f in listdir(mypath) if (isfile(join(mypath, f))and('.fits'in f))]
spectra[3]
# Out:
# 'gar3_12393651-6030146_H525.8B.fits'

# %%
HR10=data[[('H548.8' in data['FILENAME'][i]) for i in range(len(data['FILENAME']))]].reset_index()

# %% [markdown]
# # This is the HR10 bit, the H548.8

# %%
def find_file(arr):
    arr=arr.split('|')
    return [arr[i] for i in range(len(arr)) if 'H548.8' in arr[i]][0]
HR10['FILENAME']=HR10['FILENAME']

# %%
HR10['hr10_file']=HR10['FILENAME'].apply(find_file)

# %%
HR10
# Out:
#         index             CNAME   CNAME_iDR6_orig         GAIA_eDR3_ID  \
# 0           1  00000010-5727519  00000010-5727519  4919430806123101568
# 1           2  00000014-6003143  00000014-6003143  4918001166129129856
# 2           3  00000064-5739305  00000064-5739305  4919413213937060992
# 3           4  00000097-5946444  00000097-5946444  4918020201424204288
# 4           5  00000117-5951314  00000117-5951314  4918018754019017088
# ...       ...               ...               ...                  ...
# 49758  114907  23595677-5730150  23595677-5730150  6494939022065999872
# 49759  114908  23595693-5946212  23595693-5946212  6494235368984194304
# 49760  114910  23595715-5720256  23595715-5720256  6496443012237802240
# 49761  114911  23595742-5508544  23595742-5508544  6497052145975851264
# 49762  114912  23595755-5502508  23595755-5502508  6497146699679533952
#
#       DIST_GAIA       GES_FLD         OBJECT  \
# 0        0.0453  GES_MW_00_01  G_2_b_566_225
# 1        0.3006  GES_MW_00_01  G_2_r_353_228
# 2        0.0554  GES_MW_00_01  G_2_r_566_162
# 3        0.2127  GES_MW_00_01  G_2_e_353_353
# 4        0.3639  GES_MW_00_01  G_2_e_353_319
# ...         ...           ...            ...
# 49758    0.0869  GES_MW_23_24   G_2_e_566_92
# 49759    0.2763  GES_MW_23_24  G_2_e_353_184
# 49760    0.0733  GES_MW_23_24  G_2_e_566_124
# 49761    0.2539  GES_MW_23_24   G_2_e_177_92
# 49762    0.0782  GES_MW_23_24  G_2_b_177_163
#
#                                                 FILENAME GES_TYPE  \
# 0      gir_00000010-5727519_H548.8.fit|gir_00000010-5...    GE_MW
# 1      gir_00000014-6003143_H548.8.fit|gir_00000014-6...    GE_MW
# 2      gir_00000064-5739305_H548.8.fit|gir_00000064-5...    GE_MW
# 3      gir_00000097-5946444_H548.8.fit|gir_00000097-5...    GE_MW
# 4      gir_00000117-5951314_H548.8.fit|gir_00000117-5...    GE_MW
# ...                                                  ...      ...
# 49758  gir_23595677-5730150_H548.8.fit|gir_23595677-5...    GE_MW
# 49759  gir_23595693-5946212_H548.8.fit|gir_23595693-5...    GE_MW
# 49760  gir_23595715-5720256_H548.8.fit|gir_23595715-5...    GE_MW
# 49761  gir_23595742-5508544_H548.8.fit|gir_23595742-5...    GE_MW
# 49762  gir_23595755-5502508_H548.8.fit|gir_23595755-5...    GE_MW
#
#                            RA  ... E_FEH SYS_ERR_FEH   XI E_XI    VRAD E_VRAD  \
# 0      0.00041666666666665965  ...  0.07         nan  nan  nan   24.66   0.33
# 1       0.0005833333333333235  ...  0.07         nan  nan  nan  -21.32   0.11
# 2        0.002666666666666622  ...  0.07         nan  nan  nan  -16.93   0.12
# 3        0.004041666666666598  ...  0.13         nan  nan  nan   19.05   0.54
# 4        0.004874999999999918  ...   0.1         nan  nan  nan  -65.99   0.39
# ...                       ...  ...   ...         ...  ...  ...     ...    ...
# 49758       359.9865416666605  ...  0.11         nan  nan  nan  -70.87    2.0
# 49759       359.9872083333272  ...  0.11         nan  nan  nan   68.33   0.63
# 49760       359.9881249999939  ...   0.1         nan  nan  nan  -11.12   0.48
# 49761      359.98924999999394  ...  0.06         nan  nan  nan   44.11   0.67
# 49762      359.98979166666055  ...  0.11         nan  nan  nan  -34.42   0.59
#
#       VRAD_OFFSET GAMMA E_GAMMA                        hr10_file
# 0             nan   nan     nan  gir_00000010-5727519_H548.8.fit
# 1             nan   nan     nan  gir_00000014-6003143_H548.8.fit
# 2             nan   nan     nan  gir_00000064-5739305_H548.8.fit
# 3             nan   nan     nan  gir_00000097-5946444_H548.8.fit
# 4             nan   nan     nan  gir_00000117-5951314_H548.8.fit
# ...           ...   ...     ...                              ...
# 49758         nan   nan     nan  gir_23595677-5730150_H548.8.fit
# 49759         nan   nan     nan  gir_23595693-5946212_H548.8.fit
# 49760         nan   nan     nan  gir_23595715-5720256_H548.8.fit
# 49761         nan   nan     nan  gir_23595742-5508544_H548.8.fit
# 49762         nan   nan     nan  gir_23595755-5502508_H548.8.fit
#
# [49763 rows x 28 columns]

# %%
import os
os.getcwd()
os.chdir('../Parameter_files')

# %%
HR10.to_csv('HR10_parameter_with_file_names_for_spectra.csv')

# %% [markdown]
# Given the names of the spectrum files, find the file and open it.

# %%
os.chdir('../')
from Data_handling.spectra_object import get_data
os.chdir('Data')

HR10['spectrum']=HR10['hr10_file'].apply(get_data)

# %%
HR10.to_csv('HR10_full_spectra_with_parameters.csv')
